# %% [markdown]
# ![jramirezbelcognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Perfil de Linkedin = linkedin.com/in/juan-esteban-ramírez-beltrán-37750b21a

# %% [markdown]
# Python for Data Science = https://courses.cognitiveclass.ai/certificates/a2d6d44c4add43fc80f3ff0e1b62886d

# %% [markdown]
# Data Analysis with Python = https://courses.cognitiveclass.ai/certificates/20fd2ba78f924a09b988df9c00cd8d7a

# %% [markdown]
# Data Visualization with Python =
# https://courses.cognitiveclass.ai/certificates/a84cf27f76b746489c0ff67b15d5dc8b
